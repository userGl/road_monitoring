# %%
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu118

# %%
# # Установка остальных пакетов
# %pip install ultralytics
# %pip install opencv-python==4.8.0.74
# %pip install wandb

# %%
import os
import sys
from pathlib import Path
import yaml
import torch
from ultralytics import YOLO

# %%
# Проверка доступности CUDA
print(f"PyTorch версия: {torch.__version__}")
print(f"CUDA доступна: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA версия: {torch.version.cuda}")
    print(f"Количество GPU: {torch.cuda.device_count()}")
    print(f"Текущее GPU: {torch.cuda.get_device_name(0)}")
    print(f"Память GPU: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")
else:
    print("CUDA недоступна, будет использоваться CPU (тренировка будет медленнее)")
# Out:
# PyTorch версия: 2.10.0+cu130
# CUDA доступна: True
# CUDA версия: 13.0
# Количество GPU: 1
# Текущее GPU: NVIDIA GeForce RTX 4070 Laptop GPU
# Память GPU: 7.62 GB

# %%
# ---------------- БАЗОВАЯ НАСТРОЙКА ----------------
PROJECT_ROOT = Path("/home/gleb/Документы/33.VKR/mvp/road_monitoring").resolve()
os.chdir(PROJECT_ROOT)

os.environ['PYTHONIOENCODING'] = 'utf-8'
os.environ['LANG'] = 'ru_RU.UTF-8'
os.environ['LC_ALL'] = 'ru_RU.UTF-8'
if hasattr(sys.stdout, 'reconfigure'):
    sys.stdout.reconfigure(encoding='utf-8')
if hasattr(sys.stderr, 'reconfigure'):
    sys.stderr.reconfigure(encoding='utf-8')

print(f"Текущая директория: {os.getcwd()}")
print(f"Кодировка: {sys.stdout.encoding}")

model_type = "yolo11n.pt"
NAME_MODEL = "yolo11n_rdd_default_run"
DATASET_NAME = "RDD_SPLIT"

TRAINING_DIR = PROJECT_ROOT / "training"
CFG_PATH     = TRAINING_DIR / "args.yaml"
RUNS_SUBDIR = DATASET_NAME   # Поддиректория в runs для сохранения результатов (соответствует имени датасета)
DATA_PATH    = TRAINING_DIR / "datasets" / DATASET_NAME / "rdd_split.yaml"
TRAIN_MODEL  = TRAINING_DIR / "pretrained_models" / model_type
# Out:
# Текущая директория: /home/gleb/Документы/33.VKR/mvp/road_monitoring
# Кодировка: UTF-8

# %%
# ---------------- ЧТЕНИЕ И МОДИФИКАЦИЯ YAML ----------------
with open(CFG_PATH, "r", encoding="utf-8") as f:
    cfg = yaml.safe_load(f)

# переопределяем только то, что нужно
# cfg.update({
#     "model": str(TRAIN_MODEL),                      # yolov8s.pt
#     "data": str(DATA_PATH),
#     "epochs": 25,
#     "patience": 18,
#     "lr0": 0.0025,
#     "warmup_epochs": 2,
#     "cls": 0.8,
#     "scale": 0.25,
#     "device": 0 if torch.cuda.is_available() else "cpu",
#     "project": str(TRAINING_DIR / "runs" / RUNS_SUBDIR),
#     "name": NAME_MODEL,
# })

cfg.update({
    "batch": 32,
    "model": str(TRAIN_MODEL),          # yolov9s.pt
    "data": str(DATA_PATH),
    "device": 0 if torch.cuda.is_available() else "cpu",
    "project": str(TRAINING_DIR / "runs" / RUNS_SUBDIR),
    "name": NAME_MODEL,
})


print("\nИспользуемые ключевые параметры:")
for k in ["model", "data", "epochs", "lr0", "patience", "batch", "imgsz", "mosaic", "mixup", "copy_paste", "box", "cls", "dfl", "project", "name"]:
    print(f"{k}: {cfg[k]}")
# Out:
# Используемые ключевые параметры:
# model: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/pretrained_models/yolo11n.pt
# data: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/rdd_split.yaml
# epochs: 100
# lr0: 0.01
# patience: 20
# batch: 32
# imgsz: 640
# mosaic: 0.0
# mixup: 0.0
# copy_paste: 0.0
# box: 7.5
# cls: 0.5
# dfl: 1.5
# project: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/runs/RDD_SPLIT
# name: yolo11n_rdd_default_run

# %%
# ---------------- ЗАПУСК ОБУЧЕНИЯ ----------------
device = cfg["device"]
print(f"\nИспользуемое устройство: {device}")
print("Автовзвешивание классов: включено (YOLOv8)\n")

model = YOLO(cfg["model"])

results = model.train(**cfg)

print(f"\nТРЕНИРОВКА ЗАВЕРШЕНА!")
print(f"Результаты: {cfg['project']}/{cfg['name']}")
# Out:
# Используемое устройство: 0
# Автовзвешивание классов: включено (YOLOv8)
#
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11n.pt to '/home/gleb/Документы/33.VKR/mvp/road_monitoring/training/pretrained_models/yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 2.3MB/s 2.3s.2s<0.0s2.4s
# New https://pypi.org/project/ultralytics/8.4.11 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.9 🚀 Python-3.12.3 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 4070 Laptop GPU, 7806MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/rdd_split.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/home/gleb/Документы/33.VKR/mvp/road_monitoring/training/pretrained_models/yolo11n.pt, momentum=0.937, mosaic=0.0, multi_scale=0.0, name=yolo11n_rdd_default_run, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/home/gleb/Документы/33.VKR/mvp/road_monitoring/training/runs/RDD_SPLIT, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/gleb/Документы/33.VKR/mvp/road_monitoring/training/runs/RDD_SPLIT/yolo11n_rdd_default_run, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=1337, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=5, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431452  ultralytics.nn.modules.head.Detect           [4, 16, None, [64, 128, 256]]
# YOLO11n summary: 182 layers, 2,590,620 parameters, 2,590,604 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 515.5±408.2 MB/s, size: 742.3 KB)
# train: Scanning /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/labels.cache... 26869 images, 8097 backgrounds, 2599 corrupt: 100% ━━━━━━━━━━━━ 26869/26869 5.4Git/s 0.0s
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_000048.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_000057.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_000062.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_000064.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_000136.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_000160.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_000205.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_000237.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_000315.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_000404.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_000435.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_000503.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_000541.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_000690.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_000695.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_000764.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_000839.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_000942.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_000955.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_000998.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_001016.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_001050.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_001067.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_001287.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_001340.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_001401.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_001446.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_001511.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_001522.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_001531.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_001628.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_001714.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_001773.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_001805.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_001811.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_001847.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_001854.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_001940.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_001961.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_001990.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_002080.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_002137.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_002143.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_002144.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_002145.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_002190.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_Drone_002268.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000001.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000007.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000035.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000050.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000064.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000078.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000099.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000113.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000127.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000138.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000150.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000151.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000188.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000195.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000210.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000266.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000304.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000328.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000336.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000337.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000355.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000394.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000402.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000407.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000408.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000419.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000422.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000448.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000482.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000518.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000524.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000552.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000567.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000582.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000619.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000651.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000692.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000709.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000736.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000752.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000755.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000781.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000854.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000856.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000882.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000957.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000971.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000976.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_000990.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001002.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001016.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001019.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001038.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001041.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001059.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001061.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001084.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001090.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001115.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001139.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001152.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001176.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001189.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001196.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001204.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001246.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001300.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001307.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001340.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001350.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001370.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001395.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001424.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001437.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001452.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001508.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001516.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001532.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001535.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001546.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001550.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001562.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001571.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001572.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001579.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001590.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001607.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001610.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001611.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001641.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001661.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001662.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001665.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001680.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001726.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001735.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001766.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001794.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001811.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001839.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001841.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001842.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001876.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001888.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001905.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001913.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001925.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/China_MotorBike_001965.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/Czech_000064.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/Czech_000083.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/Czech_000086.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/Czech_000103.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/Czech_000270.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/Czech_000293.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/Czech_000296.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/Czech_000302.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/Czech_000343.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/Czech_000395.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/Czech_000406.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/Czech_000512.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/Czech_000568.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/Czech_000582.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/Czech_000596.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/Czech_000612.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/Czech_000634.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/Czech_000645.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/Czech_000729.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# train: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/train/images/Czech_
home/gleb/Документы/33.VKR/mvp/road_monitoring/training/runs/RDD_SPLIT/yolo11n_rdd_default_run/weights/best.pt, 5.5MB
#
# Validating /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/runs/RDD_SPLIT/yolo11n_rdd_default_run/weights/best.pt...
# Ultralytics 8.4.9 🚀 Python-3.12.3 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 4070 Laptop GPU, 7806MiB)
# YOLO11n summary (fused): 101 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 82/82 6.2it/s 13.2s0.2s
#                    all       5214       7827      0.671      0.588       0.64      0.361
#                    D00       1860       3539      0.645       0.52      0.571      0.327
#                    D10       1090       1644      0.648      0.498      0.554       0.28
#                    D20       1014       1256      0.699      0.614      0.676      0.366
#                    D40        965       1388      0.692      0.722      0.758      0.472
# Speed: 0.1ms preprocess, 1.2ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/runs/RDD_SPLIT/yolo11n_rdd_default_run
#
# ТРЕНИРОВКА ЗАВЕРШЕНА!
# Результаты: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/runs/RDD_SPLIT/yolo11n_rdd_default_run

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

csv_path = TRAINING_DIR / "runs" / RUNS_SUBDIR / NAME_MODEL / "results.csv"
# путь к CSV

df = pd.read_csv(csv_path)

# какие колонки рисовать
cols = [
    "train/box_loss",
    "train/cls_loss",
    "train/dfl_loss",
    "val/box_loss",
    "val/cls_loss",
    "val/dfl_loss",
    "metrics/precision(B)",
    "metrics/recall(B)",
    "metrics/mAP50(B)",
    "metrics/mAP50-95(B)",
]

fig, axes = plt.subplots(4, 3, figsize=(12, 12))
axes = axes.ravel()

fig.suptitle(f'Метрики обучения, файл:\n{csv_path}', fontsize=16, fontweight='bold', y=1.02)


for ax, col in zip(axes, cols):
    ax.plot(df["epoch"], df[col], label=col)
    ax.set_title(col, fontsize=12)
    ax.set_xlabel("epoch", fontsize=10)
    ax.grid(True, alpha=0.3)

# Скрываем лишние subplots (последние 2)
for ax in axes[len(cols):]:
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
from ultralytics import YOLO
from pathlib import Path

# Используем переменные из Cell 4
model_path = TRAINING_DIR / "runs" / RUNS_SUBDIR / NAME_MODEL / "weights" / "best.pt"
data_path  = DATA_PATH

model = YOLO(str(model_path))

metrics = model.val(
    data=str(data_path),
    split="test",        # важное место
    imgsz=640,
    batch=24,
    device=0,
    save_json=True,
    project=str(TRAINING_DIR / "runs/test_eval"),
    name=f"{NAME_MODEL}_test",
)

print(f'mAP@0.5-0.95 {metrics.box.map}')       # mAP@0.5-0.95
print(f'mAP@0.5 {metrics.box.map50}')    # mAP@0.5
print(f'per-class AP {metrics.box.maps}')     # per-class AP
# Out:
# Ultralytics 8.4.9 🚀 Python-3.12.3 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 4070 Laptop GPU, 7806MiB)
# YOLO11n summary (fused): 101 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.3±0.2 ms, read: 105.7±68.7 MB/s, size: 58.5 KB)
# val: Scanning /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/labels.cache... 5758 images, 1790 backgrounds, 531 corrupt: 100% ━━━━━━━━━━━━ 5758/5758 2.7Git/s 0.0s
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_Drone_000286.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_Drone_000383.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_Drone_000451.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_Drone_000487.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_Drone_001555.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_Drone_002041.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_Drone_002189.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_Drone_002372.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_MotorBike_000010.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_MotorBike_000088.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_MotorBike_000234.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_MotorBike_000296.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_MotorBike_000363.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_MotorBike_000553.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_MotorBike_000648.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_MotorBike_000786.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_MotorBike_000801.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_MotorBike_000841.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_MotorBike_000940.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_MotorBike_000985.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_MotorBike_000996.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_MotorBike_001015.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_MotorBike_001107.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_MotorBike_001217.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_MotorBike_001233.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_MotorBike_001236.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_MotorBike_001293.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_MotorBike_001419.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_MotorBike_001520.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_MotorBike_001521.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_MotorBike_001553.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_MotorBike_001578.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_MotorBike_001631.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_MotorBike_001681.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/China_MotorBike_001815.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/Czech_000010.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/Czech_000275.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/Czech_000392.jpg: ignoring corrupt image/label: Label class 4 exceeds dataset class count 4. Possible class labels are 0-3
# val: /home/gleb/Документы/33.VKR/mvp/road_monitoring/training/datasets/RDD_SPLIT/test/images/Czech_